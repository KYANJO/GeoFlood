# %%
from numpy import *
from matplotlib.pyplot import *


# %matplotlib inline
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
hu  =  20
h1 = 0
u1 = 0
g = 9.81

#  function
def f(h):
    return hu/h - 2*sqrt(g*h) - u1 + 2*sqrt(g*h1)

h = linspace(1, 20, 1000)

plot(h, f(h))
axhline(0, color='k')
grid()
xlabel
